# %% [markdown]
# <a href="https://colab.research.google.com/github/lbk209/topic_modeling/blob/main/tm_wine_reviews_params.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setting

# %%
# %%capture
# !pip install bertopic accelerate adjustText

# %%
import os
import pandas as pd
import plotly.express as px
from tqdm import tqdm

# %%
# to work with path name having blank
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %% [markdown]
# run to copy files from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# run to upload files from local

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# # 🗂️ Data

# %%
file = 'wine_reviews'
path = 'sample_data'
path_src = '/content/drive/MyDrive/Colab\ Notebooks/'

# %%
# !unzip {path_src}/{file}.zip -d {path}
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks//wine_reviews.zip
#   inflating: sample_data/wine_reviews_240124.csv
#   inflating: sample_data/wine_reviews_240207.csv

# %%
import os

files = [x for x in os.listdir(path) if x.startswith(file)]
files
# Out:
# ['wine_reviews_240207.csv', 'wine_reviews_240124.csv']

# %%
import pandas as pd

df_reviews = pd.DataFrame()
for f in files:
    df = pd.read_csv(f'{path}/{f}', parse_dates=['date'])
    df_reviews = pd.concat([df_reviews, df])

df_reviews = df_reviews.reset_index(drop=True).rename_axis('id').reset_index()
df_reviews.head()
# Out:
#    id  wid                                       wine       date  \
# 0   0    6  Casillero del Diablo Chardonnay (Reserva) 2024-02-03
# 1   1    6  Casillero del Diablo Chardonnay (Reserva) 2024-02-02
# 2   2    6  Casillero del Diablo Chardonnay (Reserva) 2024-01-29
# 3   3    6  Casillero del Diablo Chardonnay (Reserva) 2024-01-26
# 4   4    6  Casillero del Diablo Chardonnay (Reserva) 2024-01-01
#
#                                               review  source lang  \
# 0                               cu 1.6 구매, 소비뇽블랑같은 맛  vivino   ko
# 1  Chardonnay da onipresente Concha y Toro. É agr...  vivino   pt
# 2  Aroma de pêssego bem presente!! Harmoniza bem ...  vivino   pt
# 3  It's a pretty rough Chardonnay, unbalanced and...  vivino   en
# 4                                Bom custo beneficio  vivino   en
#
#                                        review_transl
# 0      Purchased cu 1.6, tastes like sauvignon blanc
# 1  Chardonnay from the ubiquitous Concha y Toro. ...
# 2  Peach aroma very present!! Pairs well with sea...
# 3  It's a pretty rough Chardonnay, unbalanced and...
# 4                                  Good cost-benefit

# %% [markdown]
# ## Review data

# %% [markdown]
# **reviews not translated**

# %%
import numpy as np

#df_reviews.loc[df_reviews.lang.str.contains('ERROR')]

cond = df_reviews.review_transl.isna()
df_reviews.loc[cond]
# Out:
#         id  wid                                               wine       date  \
# 164    164    7  Kendall-Jackson Vintner's Reserve Cabernet Sau... 2023-03-18
# 438    438    9                        Frontera Cabernet Sauvignon 2022-05-21
# 484    484    9                        Frontera Cabernet Sauvignon 2022-01-24
# 771    771   12                 The 7th Generation - G7 Chardonnay 2022-01-31
# 975    975   13                    San Pedro Gato Negro Chardonnay 2022-04-27
# 1360  1360   18             Montes Montes Alpha Cabernet Sauvignon 2022-12-19
# 1476  1476   18             Montes Montes Alpha Cabernet Sauvignon 2021-12-24
#
#        review  source           lang review_transl
# 164       :-)  vivino  <-- ERROR -->           NaN
# 438         😡  vivino  <-- ERROR -->           NaN
# 484        🤌🏻  vivino  <-- ERROR -->           NaN
# 771      🌵🍏🥝🧈  vivino  <-- ERROR -->           NaN
# 975   … …. ….  vivino  <-- ERROR -->           NaN
# 1360      ♡♡♡  vivino  <-- ERROR -->           NaN
# 1476        .  vivino  <-- ERROR -->           NaN

# %%
df_reviews = df_reviews.loc[~cond]

# %%
#df_reviews.groupby(['wid', 'wine']).review_transl.count()
df_reviews.groupby(['wid', 'wine']).id.count()
# Out:
# wid  wine
# 0    Casillero del Diablo Cabernet Sauvignon (Reserva)       472
# 1    Yellow Tail Cabernet Sauvignon                          136
# 2    Roche Mazet Cuvée Spéciale Cabernet Sauvignon            61
# 3    San Pedro Gato Negro Cabernet Sauvignon                 879
# 4    Aguirre Dos Copas Cabernet Sauvignon                      7
# 5    The 7th Generation - G7 Cabernet Sauvignon               26
# 6    Casillero del Diablo Chardonnay (Reserva)               122
# 7    Kendall-Jackson Vintner's Reserve Cabernet Sauvignon    121
# 8    Viña Santa Helena Reservado Cabernet Sauvignon'          51
# 9    Frontera Cabernet Sauvignon                             207
# 10   Long Barn Chardonnay                                    142
# 11   Cono Sur Bicicleta Reserva Unoaked Chardonnay           109
# 12   The 7th Generation - G7 Chardonnay                       42
# 13   San Pedro Gato Negro Chardonnay                         230
# 14   Roche Mazet Cuvée Spéciale Chardonnay                    31
# 15   Yellow Tail Chardonnay                                  122
# 16   San Pedro 1865 Selected Vineyards Cabernet Sauvignon     41
# 17   San Pedro 1865 Single Vineyard Cabernet Sauvignon        42
# 18   Montes Montes Alpha Cabernet Sauvignon                  220
# Name: id, dtype: int64

# %%
df_reviews.id.count()
# Out:
# 3061

# %% [markdown]
# check wines of small numbers of reviews

# %%
df = df_reviews.groupby(by=['wid','wine']).id.count().rename('count').reset_index(1)
swid = df.loc[df['count']>100]
swid
# Out:
#                                                   wine  count
# wid
# 0    Casillero del Diablo Cabernet Sauvignon (Reserva)    472
# 1                       Yellow Tail Cabernet Sauvignon    136
# 3              San Pedro Gato Negro Cabernet Sauvignon    879
# 6            Casillero del Diablo Chardonnay (Reserva)    122
# 7    Kendall-Jackson Vintner's Reserve Cabernet Sau...    121
# 9                          Frontera Cabernet Sauvignon    207
# 10                                Long Barn Chardonnay    142
# 11       Cono Sur Bicicleta Reserva Unoaked Chardonnay    109
# 13                     San Pedro Gato Negro Chardonnay    230
# 15                              Yellow Tail Chardonnay    122
# 18              Montes Montes Alpha Cabernet Sauvignon    220

# %%
#df_reviews = df_reviews.loc[df_reviews.wid.isin(swid.index)]
df_reviews.id.count()
# Out:
# 3061

# %%
# DO NOT CHANGE the (document) id as it is index to topics of topic model (topic_model.topics_)
docs = df_reviews.review_transl.tolist()

# %% [markdown]
# # 🗨️ **BERTopic**

# %% [markdown]
# ## Params

# %% [markdown]
# ### Embedding

# %%
# 12-layer, 384-hidden
st_id = 'all-MiniLM-L12-v2'

# %% [markdown]
# ### Dimensionality Reduction

# %%
n_components = 15
n_neighbors = 10

# the minimum distance apart that points are allowed to be in the low dimensional representation.
# This means that low values of min_dist will result in clumpier embeddings.
# This can be useful if you are interested in clustering, or in finer topological structure.
# Larger values of min_dist will prevent UMAP from packing points together and will focus on the preservation of the broad topological structure instead.
min_dist = 0 #0.1

random_state=42

# %% [markdown]
# ### Clustering

# %%
# a lower min_cluster_size will generate more topics
min_cluster_size = 50

# The implementation defaults this value (if it is unspecified) to whatever min_cluster_size is set to.
# The larger the value of min_samples you provide, the more conservative the clustering – more points will be declared as noise,
# and clusters will be restricted to progressively more dense area
#min_samples = None
r = 0.6
min_samples = round(min_cluster_size*r)

# We need this to avoid an AttributeError when integrating our custom HDBSCAN step with BERTopic
prediction_data=True

# can improve the resultant clusters
gen_min_span_tree=True

# %% [markdown]
# ### BERTopic

# %%
# top n words in combined documents in a cluster
top_n_words = 5 #10

# Calculate the probabilities of all topics per document instead of the probability of the assigned topic per document.
# This could slow down the extraction of topics if you have many documents (> 100_000).
calculate_probabilities=False

# %% [markdown]
# ## **Sub-models**

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer(st_id)
embeddings = embedding_model.encode(docs, show_progress_bar=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Batches:   0%|          | 0/87 [00:00<?, ?it/s]

# %%
from umap import UMAP

umap_model = UMAP(
    n_components=n_components,
    n_neighbors=n_neighbors,
    min_dist=min_dist,
    metric='cosine', random_state=random_state)

# %%
# Pre-reduce embeddings for visualization purposes
reduced_embeddings = UMAP(n_neighbors=n_neighbors, n_components=2, min_dist=min_dist, metric='cosine', random_state=random_state).fit_transform(embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from hdbscan import HDBSCAN

hdbscan_model = HDBSCAN(
    min_cluster_size=min_cluster_size,
    min_samples=min_samples,
    metric='euclidean',
    cluster_selection_method='eom',
    prediction_data=prediction_data,
    gen_min_span_tree=gen_min_span_tree
    )

# %%
from bertopic.representation import KeyBERTInspired

keybert = KeyBERTInspired()

representation_model = {
    "KeyBERT": keybert
}

# %% [markdown]
# CountVectorizer before training the topic model to minimize the size of the resulting c-TF-IDF matrix:

# %%
min_df = 0.001
len(docs), min_df * len(docs)
# Out:
# (2760, 2.7600000000000002)

# %%
from sklearn.feature_extraction.text import CountVectorizer

#vectorizer_model = None
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 3), min_df=min_df)

# %% [markdown]
# ## 🔥 **Training**
#
# Now that we have our models prepared, we can start training our topic model! We supply BERTopic with the sub-models of interest, run `.fit_transform`, and see what kind of topics we get.

# %%
from bertopic import BERTopic

topic_model = BERTopic(
  # Sub-models
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,
  representation_model=representation_model,
  vectorizer_model=vectorizer_model,

  top_n_words=top_n_words,
  calculate_probabilities=calculate_probabilities,
  verbose=True
)

# Train model
topics, probs = topic_model.fit_transform(docs, embeddings)
# Out:
# 2024-02-07 10:16:28,985 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-02-07 10:16:47,455 - BERTopic - Dimensionality - Completed ✓
# 2024-02-07 10:16:47,457 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-02-07 10:16:47,671 - BERTopic - Cluster - Completed ✓
# 2024-02-07 10:16:47,678 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-02-07 10:16:50,375 - BERTopic - Representation - Completed ✓

# %%
# num of topics
len(topic_model.get_topics()) - 1
# Out:
# 2

# %%
# Show topics
topic_model.get_topic_info().head(7)
# Out:
#    Topic  Count                               Name  \
# 0     -1     96  -1_good_good good_gato_gato negro
# 1      0   2573              0_wine_good_oak_taste
# 2      1     91   1_chardonnay_citrus_acidity_good
#
#                                   Representation  \
# 0     [good, good good, gato, gato negro, negro]
# 1                  [wine, good, oak, taste, red]
# 2  [chardonnay, citrus, acidity, good, tropical]
#
#                                              KeyBERT  \
# 0  [good, good good, good good good, best, good l...
# 1  [good wine, wine, good, alcohol, bad, good val...
# 2  [nice chardonnay, chardonnay, good chardonnay,...
#
#                                  Representative_Docs
# 0                       [Very good, Very good, Good]
# 1            [Good wine!!, Good wine., A good wine.]
# 2  [Fruity Chardonnay, Nice chardonnay, Not my Ch...

# %% [markdown]
# ## 💦 **Post-processing**

# %% [markdown]
# ### Vectorizer
# Pass the CountVectorizer after training where llm used full context in training => ???

# %%
try:
    vectorizer_model
    print('vectorizer_model assigned before!')
except:
    print('passing vectorizer_model ater training')
# Out:
# vectorizer_model assigned before!

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#stop_additional = ['cabernet', 'sauvignon', 'cab', 'wine']
stop_additional = []

ngram_range = (1, 3)

# When building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold.
# This value is also called cut-off in the literature.
# If float, the parameter represents a proportion of documents, integer absolute counts
min_df = 10

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

# Fine-tune topic representations after training BERTopic
# you can pass the CountVectorizer before and after training your topic model.
# Passing it before training allows you to minimize the size of the resulting c-TF-IDF matrix

stopwords = list(stopwords.words('english')) + stop_additional

vectorizer_model = CountVectorizer(stop_words=stopwords, ngram_range=ngram_range, min_df=min_df)

topic_model.update_topics(docs, vectorizer_model=vectorizer_model, top_n_words=top_n_words)

# %%
topic_model.get_topic_info().head(7)
# Out:
#    Topic  Count                               Name  \
# 0     -1    580  -1_chardonnay_good_citrus_acidity
# 1      0   1166           0_oak_vanilla_good_taste
# 2      1    781           1_wine_good_cabernet_red
# 3      2    233     2_good_value_money_value money
#
#                               Representation  \
# 0  [chardonnay, good, citrus, acidity, wine]
# 1        [oak, vanilla, good, taste, cherry]
# 2         [wine, good, cabernet, red, price]
# 3     [good, value, money, value money, bad]
#
#                                              KeyBERT  \
# 0  [good, great, best, nice, better, good cost, g...
# 1  [chocolate oak, oak blackberry, oak vanilla, o...
# 2  [good wine, wine good, nice wine, great wine, ...
# 3  [good value money, good value, excellent value...
#
#                                  Representative_Docs
# 0               [Good, Very good, Not my Chardonnay]
# 1  [oak cherry black cherry chocolate blackcurran...
# 2          [Very good wine, Good wine., Good wine!!]
# 3  [Good value for money, Good value for money, V...

# %% [markdown]
# ### Outlier reduction

# %%
# Use the "c-TF-IDF" strategy with a threshold
# threshold is the minimum similarity.
new_topics = topic_model.reduce_outliers(docs, topics , strategy="c-tf-idf", threshold=0.1)

# count outliers
len([x for x in new_topics if x < 0])
# Out:
# 6455

# %%
t = topics
#t = new_topics

new_topics = topic_model.reduce_outliers(docs, t , strategy="distributions", threshold=0.5)

# count outliers
len([x for x in new_topics if x < 0])
# Out:
# 100%|██████████| 7/7 [00:22<00:00,  3.25s/it]
# 6231

# %%
t = topics
#t = new_topics
new_topics = topic_model.reduce_outliers(docs, t, strategy="embeddings", threshold=0.5)

# count outliers
len([x for x in new_topics if x < 0])
# Out:
# 1988

# %%
t = topics
#t = new_topics

# the threshold is minimum probability when strategy="probabilities"
new_topics = topic_model.reduce_outliers(docs, t, strategy="probabilities", probabilities=probs, threshold=0.05)

# count outliers
len([x for x in new_topics if x < 0])
# Out:
# 6678

# %% [markdown]
# #### update with new_topics

# %%
topic_model.update_topics(docs, topics=new_topics)
# Out:
# 2024-01-22 01:08:32,468 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %% [markdown]
# # 📊 Visualization

# %%
titles = [x[:100] for x in docs]
topics_to_visualize = range(20)

topic_model.visualize_documents(titles, reduced_embeddings=reduced_embeddings,
                                hide_annotations=True, hide_document_hover=False,
                                topics=topics_to_visualize,
                                #custom_labels=True
                                )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cae0638a-54bb-41ae-a460-4a625c46dbd9" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cae0638a-54bb-41ae-a460-4a625c46dbd9")) {                    Plotly.newPlot(                        "cae0638a-54bb-41ae-a460-4a625c46dbd9",                        [{"hoverinfo":"text","hovertext":["Highly saturated","Another Gato, Like music through my body, just like a vibrato, Mineur quite liked it, Just suck, don","Light wine with strawberry notes (not sweet). Fresh and fruity on the palate. Slightly acidic at fir","Bom","Very good","Very good","Tasty!","Bom","Bom","Bom","Tasty","Buttery yellow color, low acidity and light body.","Tasty","Good","Very good","quite good","Nomnomnom","good","Very good","Very good! If its acidity were lower, it would be better.","Tasty","Good","Bom","Very good","Very good, I would buy again","Very good","Gato. Negro. Simple. Honest. Cheap. Oak. Cherry.","Very very","Very good!","Light, moderate acidity, lemony","Very acidic, rich for clericot but not alone.","Good","Very good!","Good","Very good","Too acidic and dry, it can be seen with a good cooking","Good shit","Very good","Bom","Good","Very good.","Gato negro is best enjoyed from cardboard, they say. It delivered pretty much exactly what I expecte","Very good","Bom.","Very good, I liked it","very good!","good","Very interesting","Tasty","Too acidic mediocre","Very good","Very good thank you","Tasty","Cn\u002fs very aromatic acidity\u002fminerality in measure cxb","Good","Very good","Bom","Very good, it almost cured my depression by dani","Dry, proper acidity","Gato Negro Chardonnay is a golden yellow color and tropical aromas, with notes of peach, banana and ","Very good","Very good","Acid","It is a very smooth wine, for those new to this world of wine, Gato Negro is a good option.","Good for the day","good","Good","citrine","Bom","Very good","good","Mt bom!","Very good","Very good","Tasty","Very acidic","Lots of acidity","This wine was bought at home to put in the sauce. Was immediately worried that the sauce would be us","Pfiouuuuu, an unappreciable gato negro. Already the name does not seem too relevant to me given the ","good","Good","Surprisingly good","Strong acidity","Very good","I like the Gato Negro because is a classical good wine. Is a fruited wine and the your acid is very ","very good !","Tasty!","Dirty acid","3.5\u2b50 I liked this Gato Negro, which is widely sold here in Brazil! It went well with a barbecue. Che","Despite its subtle name, Gato Negro is a classic red wine without specificity which unfortunately su","A little high acidity","Intense color and high acidity.","But it's easy to have too much acid but at the limit","Good","Seems a little more acidic than normal","More acidic than I expected, but just learning",null],"marker":{"color":"#CFD8DC","opacity":0.5,"size":5},"mode":"markers+text","name":"other","showlegend":false,"x":[3.5706381797790527,-1.2131346464157104,-1.2153830528259277,2.8169875144958496,1.1597601175308228,1.165536880493164,0.38322946429252625,2.816908597946167,2.816761016845703,2.8167881965637207,0.3832484185695648,3.525498867034912,0.3752535581588745,-3.1259331703186035,1.1636831760406494,1.1671414375305176,2.817209243774414,-3.12626314163208,1.1651579141616821,3.5124709606170654,0.3857961893081665,-3.1265869140625,2.816911220550537,1.1533725261688232,1.134336233139038,1.167291283607483,-1.2149722576141357,1.171099305152893,1.1722815036773682,3.5985257625579834,3.5456924438476562,-3.1262619495391846,1.1713024377822876,-3.1265039443969727,1.1680306196212769,3.526665687561035,-3.126535177230835,1.154008388519287,2.8169124126434326,-3.124821424484253,1.1628682613372803,-1.215470552444458,1.1677742004394531, ...

# %% [markdown]
# ## Topics per Class

# %%
classes = df_reviews.wine.tolist()
topics_per_class = topic_model.topics_per_class(docs, classes=classes)
# Out:
# 11it [00:00, 15.52it/s]

# %%
custom_labels = True
normalize_frequency = False

# %%
topic_model.visualize_topics_per_class(topics_per_class, top_n_topics=10,
                                       normalize_frequency = normalize_frequency,
                                       width=1000, height=500,
                                       custom_labels=custom_labels)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dd8fe87a-688d-4190-a0e5-8e8a927714c5" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd8fe87a-688d-4190-a0e5-8e8a927714c5")) {                    Plotly.newPlot(                        "dd8fe87a-688d-4190-a0e5-8e8a927714c5",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, citrus, oak, vanilla","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, citrus, pineapple, tropical","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, oak, taste, black","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, vanilla, good, oak, taste","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: oak, wine, vanilla, taste, butter","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, red, taste, fruity","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, sweet, oak, vanilla","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, oak, cherry, blackberry, black","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, oak, cherry, red","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, citrus, fruity, taste","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, taste, oak, red"],"marker":{"color":"#E69F00"},"name":"0_wine_good_oak_taste","orientation":"h","visible":true,"x":[90,98,215,102,120,831,130,120,459,206,202],"y":["Casillero del Diablo Chardonnay (Reserva)","Cono Sur Bicicleta Reserva Unoaked Chardonnay","Montes Montes Alpha Cabernet Sauvignon","Yellow Tail Chardonnay","Long Barn Chardonnay","San Pedro Gato Negro Cabernet Sauvignon","Yellow Tail Cabernet Sauvignon","Kendall-Jackson Vintner's Reserve Cabernet Sauvignon","Casillero del Diablo Cabernet Sauvignon (Reserva)","San Pedro Gato Negro Chardonnay","Frontera Cabernet Sauvignon"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, citrus, good, acidity, butter","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, tropical, citrus, acidity, fresh","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, good, notes, citrus, white","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, oaky, oak, tropical, acidity","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: caesar, drank caesar windsor, caesar windsor court, caesar windsor, windsor court honey","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chilean chardonnay, acidity, citrus, peach"],"marker":{"color":"#56B4E9"},"name":"1_chardonnay_citrus_acidity_good","orientation":"h","visible":"legendonly","x":[28,11,15,20,1,16],"y":["Casillero del Diablo Chardonnay (Reserva)","Cono Sur Bicicleta Reserva Unoaked Chardonnay","Yellow Tail Chardonnay","Long Barn Chardonnay","San Pedro Gato Negro Cabernet Sauvignon","San Pedro Gato Negro Chardonnay"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":" ...

# %% [markdown]
# **Share of reviews**

# %%
total_freq = df_reviews.groupby('wine').count().id.to_dict() # num of documents per class

df = topics_per_class.assign(Frequency=topics_per_class.apply(lambda x: x.Frequency/total_freq[x.Class], axis=1))

sum([v for k,v in total_freq.items()]), len(docs)
# Out:
# (2760, 2760)

# %%
total_freq
# Out:
# {'Casillero del Diablo Cabernet Sauvignon (Reserva)': 472,
#  'Casillero del Diablo Chardonnay (Reserva)': 122,
#  'Cono Sur Bicicleta Reserva Unoaked Chardonnay': 109,
#  'Frontera Cabernet Sauvignon': 207,
#  "Kendall-Jackson Vintner's Reserve Cabernet Sauvignon": 121,
#  'Long Barn Chardonnay': 142,
#  'Montes Montes Alpha Cabernet Sauvignon': 220,
#  'San Pedro Gato Negro Cabernet Sauvignon': 879,
#  'San Pedro Gato Negro Chardonnay': 230,
#  'Yellow Tail Cabernet Sauvignon': 136,
#  'Yellow Tail Chardonnay': 122}

# %%
topic_model.visualize_topics_per_class(df, top_n_topics=10,
                                       normalize_frequency = normalize_frequency,
                                       width=1000, height=500,
                                       custom_labels=custom_labels)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7d8023fb-8bb9-489f-80f1-0a19397742cc" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d8023fb-8bb9-489f-80f1-0a19397742cc")) {                    Plotly.newPlot(                        "7d8023fb-8bb9-489f-80f1-0a19397742cc",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, citrus, oak, vanilla","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, citrus, pineapple, tropical","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, oak, taste, black","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, vanilla, good, oak, taste","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: oak, wine, vanilla, taste, butter","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, red, taste, fruity","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, sweet, oak, vanilla","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, oak, cherry, blackberry, black","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, oak, cherry, red","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, citrus, fruity, taste","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wine, good, taste, oak, red"],"marker":{"color":"#E69F00"},"name":"0_wine_good_oak_taste","orientation":"h","visible":true,"x":[0.7377049180327869,0.8990825688073395,0.9772727272727273,0.8360655737704918,0.8450704225352113,0.9453924914675768,0.9558823529411765,0.9917355371900827,0.972457627118644,0.8956521739130435,0.9758454106280193],"y":["Casillero del Diablo Chardonnay (Reserva)","Cono Sur Bicicleta Reserva Unoaked Chardonnay","Montes Montes Alpha Cabernet Sauvignon","Yellow Tail Chardonnay","Long Barn Chardonnay","San Pedro Gato Negro Cabernet Sauvignon","Yellow Tail Cabernet Sauvignon","Kendall-Jackson Vintner's Reserve Cabernet Sauvignon","Casillero del Diablo Cabernet Sauvignon (Reserva)","San Pedro Gato Negro Chardonnay","Frontera Cabernet Sauvignon"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, citrus, good, acidity, butter","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, tropical, citrus, acidity, fresh","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, good, notes, citrus, white","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, oaky, oak, tropical, acidity","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: caesar, drank caesar windsor, caesar windsor court, caesar windsor, windsor court honey","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chilean chardonnay, acidity, citrus, peach"],"marker":{"color":"#56B4E9"},"name":"1_chardonnay_citrus_acidity_good","orientation":"h","visible":"legendonly","x":[0.22950819672131148,0.10091743119266056,0.12295081967213115,0.14084507042253522,0.0011376564277588168,0.06956521739130435],"y":["Casillero del Diablo Chardonnay (Reserva)","Cono Sur Bicicleta Reserva Unoaked Chardonnay","Yellow Tail Chardonnay","Long Barn Chardonnay","San Pedro Gato Negro Cabernet Sauvignon","San Pedro Gato Negro Chardonnay"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endli ...

# %% [markdown]
# # 🎚️ **Parameter Study**

# %%
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from bertopic.representation import KeyBERTInspired
from sklearn.feature_extraction.text import CountVectorizer
from bertopic import BERTopic


def bertopic_param_search(docs,
                   ### hyperparams
                   min_df=1, # CountVectorizer
                   n_components=15,
                   n_neighbors=10,
                   min_dist=0.1, # UMAP
                   min_cluster_size=10,
                   min_samples=None, # HDBSCAN
                   ####
                   embedding_model=None,
                   embeddings=None,
                   ngram_range=(1, 3),
                   prediction_data=True,
                   gen_min_span_tree=True,
                   top_n_words=5,
                   calculate_probabilities=False,
                   random_state=42,
                   verbose=False
                   ):

    #-- sub-models
    vectorizer_model = CountVectorizer(stop_words="english", ngram_range=ngram_range, min_df=min_df)

    umap_model = UMAP(
        n_components=n_components,
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        metric='cosine', random_state=random_state)

    hdbscan_model = HDBSCAN(
        min_cluster_size=min_cluster_size,
        min_samples=min_samples,
        metric='euclidean',
        cluster_selection_method='eom',
        prediction_data=prediction_data,
        gen_min_span_tree=gen_min_span_tree
        )

    keybert = KeyBERTInspired()
    representation_model = {
        "KeyBERT": keybert
    }

    #-- train bertopic
    topic_model = BERTopic(
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer_model,
        representation_model=representation_model,

        top_n_words=top_n_words,
        calculate_probabilities=calculate_probabilities,
        verbose=verbose
    )

    # Train model
    try:
        topics, probs = topic_model.fit_transform(docs, embeddings)
        df = topic_model.get_topic_info()
    except:
        df = None

    return df


def get_topics(df, index, num_topics=10, cols = ['Topic', 'KeyBERT']):
    """
    get a row from df, the result of bertopic_param_search
    index: index of a param set
    """
    return df.iloc[1:num_topics+1].loc[:, cols].rename(columns=dict(zip(cols, ['index', index]))).set_index('index').transpose()

# %% [markdown]
# ## Set params

# %%
params_study = {
    # When CountVectorizer building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold.
    # If float, the parameter represents a proportion of documents, integer absolute counts
    'min_df': [1, 10], #[0.001, 0.01],

    # If you are interested in (density based) clustering, or other machine learning techniques,
    # it can be beneficial to pick a larger embedding dimension (say 10, or 50) closer to the the dimension
    # of the underlying manifold on which your data lies.
    'n_components': [10, 20, 50],

    # how UMAP balances local versus global structure in the data.
    # low values of n_neighbors will force UMAP to concentrate on very local structure (potentially to the detriment of the big picture)
    'n_neighbors': [10, 20, 50],

    # the minimum distance apart that points are allowed to be in the low dimensional representation.
    # This means that low values of min_dist will result in clumpier embeddings.
    # This can be useful if you are interested in clustering, or in finer topological structure.
    # Larger values of min_dist will prevent UMAP from packing points together and will focus on the preservation of the broad topological structure instead.
    'min_dist': [0, 0.05, 0.1],

    # set it to the smallest size grouping that you wish to consider a cluster.
    # It can have slightly non-obvious effects with min_samples
    'min_cluster_size': [20, 50, 100],

    # The implementation defaults this value (if it is unspecified) to whatever min_cluster_size is set to.
    # The larger the value of min_samples you provide, the more conservative the clustering –
    # more points will be declared as noise, and clusters will be restricted to progressively more dense area
    # UPDATE as the values are ratio to min_cluster_size
    'min_samples': [0.1, 0.5, 1.]
}

# %%
# Embedding model: 12-layer, 384-hidden
st_id = 'all-MiniLM-L12-v2'

params_base = {
    'ngram_range': (1, 3),
    'top_n_words': 5,
    'random_state': 42,
}

# %% [markdown]
# Product param sets

# %%
from itertools import product

param_names = params_study.keys()

param_values = params_study.values()
param_values = list(product(*param_values))

df_params = pd.DataFrame(param_values, columns=param_names)

try:
    df_params.min_samples = df_params.min_samples.mul(df_params.min_cluster_size).astype(int)
except:
    print('No min_samples')

df_params = df_params.reset_index(drop=True)
df_params.head(5)
# Out:
#    min_df  n_components  n_neighbors  min_dist  min_cluster_size  min_samples
# 0       1            10           10       0.0                20            2
# 1       1            10           10       0.0                20           10
# 2       1            10           10       0.0                20           20
# 3       1            10           10       0.0                50            5
# 4       1            10           10       0.0                50           25

# %%
len(df_params)
# Out:
# 486

# %%
df_result = pd.read_csv('sample_data/wr_param_study_01.csv')
df_result.head(5)
# Out:
#    min_df  n_components  n_neighbors  min_dist  min_cluster_size  min_samples  \
# 0       1            10           10       0.0                20            2
# 1       1            10           10       0.0                20           10
# 2       1            10           10       0.0                20           20
# 3       1            10           10       0.0                50            5
# 4       1            10           10       0.0                50           25
#
#                                                    0  \
# 0  ['fruity', 'delicious fruity', 'fruity good', ...
# 1  ['nice wine', 'good wine', 'great wine', 'exce...
# 2  ['good', 'great', 'excellent', 'bad', 'good va...
# 3  ['good wine', 'wine', 'sauvignon', 'cabernet s...
# 4  ['good', 'great', 'excellent', 'good value', '...
#
#                                                    1  \
# 0  ['good value money', 'money good value', 'good...
# 1  ['vanilla oak blackberry', 'oak blackberry van...
# 2  ['nice chardonnay', 'chardonnay', 'good chardo...
# 3  ['nice chardonnay', 'chardonnay', 'good chardo...
# 4  ['nice chardonnay', 'chardonnay', 'good chardo...
#
#                                                    2  \
# 0  ['chilean cabernet sauvignon', 'cabernet sauvi...
# 1  ['nice chardonnay', 'good chardonnay', 'chardo...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    3  \
# 0  ['citrus tropical', 'citrus pear tropical', 'p...
# 1  ['fruity', 'fruity good', 'tasty fruity', 'swe...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    4  \
# 0  ['chilean wine', 'wine chile', 'chilean wine w...
# 1  ['sour taste', 'bitter', 'retrospect add taste...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    5  \
# 0  ['oak', 'oak oak', 'vanilla oak', 'oak vanilla...
# 1  ['good value money', 'money good value', 'good...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    6  \
# 0  ['fruity scent', 'citrus scent', 'aromatic fru...
# 1  ['drink easy', 'easy drinking', 'easy drink', ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    7  \
# 0  ['håkon rekdal', 'like håkon rekdal', 'rekdal'...
# 1  ['citrus tropical', 'citrus pear tropical', 'p...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    8  \
# 0  ['medium tannins', 'medium tannin', 'soft tann...
# 1  ['smooth dry', 'flavor smooth', 'dry smooth', ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    9
# 0  ['easy drink good', 'drink easy', 'easy drinki...
# 1  ['cabernet sauvignon', 'chilean cabernet sauvi...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# Update base params with embedding model

# %%
show_progress_bar=False,

embedding_model = SentenceTransformer(st_id)
embeddings = embedding_model.encode(docs, show_progress_bar=show_progress_bar)
# Out:
# Batches:   0%|          | 0/96 [00:00<?, ?it/s]

# %%
params_base.update({
    'embedding_model': embedding_model,
    'embeddings': embeddings
})

# %% [markdown]
# ## Search params

# %%
#df_result = pd.DataFrame()

# num of param sets searched before
len(df_result)
# Out:
# 231

# %%
total = len(df_params)
#total = 3 # testing

for rec in tqdm(df_params.iloc[:total].itertuples(), total=total):
    idx = rec[0]
    kwargs = rec._asdict()
    kwargs.pop('Index', None)

    # filter param set
    cond = (df_result[list(kwargs)] == pd.Series(kwargs)).all(axis=1)
    if cond.sum() > 0:
        continue

    kwargs.update(params_base)
    df = bertopic_param_search(docs, **kwargs)

    if df is None:
        df = pd.DataFrame({0: ['ERROR']}).rename_axis('index')
    else:
        df = get_topics(df, idx)
    df_result = pd.concat([df_result, df])

df_result = df_params.join(df_result)
df_result.head(5)
# Out:
#  56%|█████▌    | 272/486 [15:02<1:09:16, 19.42s/it]

# %% [markdown]
# join param set to result if param search interupted

# %%
#df_result = df_params.loc[df_result.index].join(df_result)
#len(df_result)

# %%
cond = df_result[0].isna()
print('num of param sets to be studied:', cond.sum())

#df_result = df_result.loc[~cond]

df_result.loc[cond].head()
# Out:
# num of param sets to be studied: 0

# %%
# compare topics
topic_id = 0
num_topics = 5

_ = [print(f'{i:>2}:', ', '.join(rec[topic_id][:num_topics])) for i, rec in df_result.iterrows()]
# Out:
#  0: fruity, delicious fruity, fruity good, tasty fruity, sweet fruity
#  1: nice wine, good wine, great wine, excellent wine, wine good
#  2: good, great, excellent, bad, good value
#  3: good wine, wine, sauvignon, cabernet sauvignon, alcohol
#  4: good, great, excellent, good value, bad
#  5: good wine, good, bad, wine, good value
#  6: nice wine, good wine, great wine, excellent wine, wine good
#  7: vanilla oak, oak vanilla, chocolate oak, oak, oak cherry
#  8: vanilla oak, oak vanilla, chocolate oak, oak cherry, oak
#  9: chardonnay chile, chilean chardonnay, nice chardonnay, chardonnay, good chardonnay
# 10: good wine, wine good wine, wine good, nice wine, excellent wine
# 11: good wine, excellent wine, wine good wine, wine good, nice wine
# 12: good value, good, quality, great, bad
# 13: good wine, wine, good value, sauvignon, cabernet sauvignon
# 14: vanilla oak, oak vanilla, oak, oak cherry, oak blackberry
# 15: good wine, wine good wine, wine good, nice wine, excellent wine
# 16: vanilla oak, oak vanilla, oak, oak cherry, oak blackberry
# 17: oak vanilla, vanilla oak, chocolate oak, oak cherry, oak
# 18: red wine, wines, good wine, wine, white wine
# 19: good wine, nice wine, excellent wine, great wine, wine good
# 20: good wine, excellent wine, nice wine, wine good, great wine
# 21: good wine, good value, wines, wine, value
# 22: good wine, wine, wines, bad, good
# 23: oak, vanilla oak, oak vanilla, chocolate oak, oak blackberry
# 24: good wine, nice wine, excellent wine, wine good, wine good wine
# 25: chocolate oak, vanilla oak, oak blackberry, oak vanilla, oak
# 26: chocolate oak, oak cherry, vanilla oak, oak, oak vanilla
# 27: good value money, money good value, good value, money excellent value, excellent value money
# 28: good wine, nice wine, wine good, excellent wine, great wine
# 29: good wine, excellent wine, nice wine, wine good, great wine
# 30: oak vanilla, oak, bad, good, oak blackberry
# 31: vanilla oak, oak vanilla, oak blackberry, oak, black cherry
# 32: oak vanilla, vanilla, oak, bad, good
# 33: oak, oak vanilla, oak blackberry, chocolate, flavors
# 34: oak vanilla, oak, oak blackberry, chocolate, vanilla
# 35: oak vanilla, oak, oak blackberry, black cherry, sweetness
# 36: good value money, money good value, good value, money excellent value, excellent value money
# 37: good wine, wine, good value, sauvignon, cabernet sauvignon
# 38: good wine, wine, good value, sauvignon, cabernet sauvignon
# 207: good value money, money good value, good value, money excellent value, excellent value money
# 208: good wine, nice wine, excellent wine, great wine, wine good
# 209: good wine, excellent wine, wine good, wine good wine, nice wine
# 210: good wine, good value, good, great, excellent
# 211: bad, good value, good, great, quality
# 212: vanilla oak, oak vanilla, chocolate oak, oak, oak blackberry
# 213: good wine, nice wine, excellent wine, great wine, wine good
# 214: vanilla oak, oak vanilla, chocolate oak, oak, oak blackberry
# 215: oak blackberry, vanilla oak, oak vanilla, chocolate oak, oak cherry
# 216: good wine, nice wine, wine good wine, wine good, excellent wine
# 217: good wine, nice wine, excellent wine, great wine, wine good wine
# 218: good wine, excellent wine, wine good, nice wine, wine good wine
# 219: good, great, excellent, bad, good value
# 220: good, great, excellent, bad, nice
# 221: great, good, excellent, good value, bad
# 222: good, bad, great, good value, excellent
# 223: good, great, excellent, good value, bad
# 224: oak vanilla, vanilla oak, chocolate oak, oak, oak blackberry
# 225: wine good value, value wine, value money wine, quality wine, cheap wine
# 227: good wine, wine good, nice wine, great wine, wine
# 229: good, good wine, good value, great, excellent
# 230: good, great, excellent, bad, good value
# 231: vanilla oak, chocolate oak, oak vanilla, oak, oak cherry
# 232: chocolate oak, oak vanilla, vanilla oak, oak blackberry, oak
# 233: chocolate oak, vanilla oak, oak, oak vanilla, oak blackberry
# 236: good wine, good, wine, great, excellent
# 238: good, great, excellent, best, good wine
# 239: good wine, good, great, excellent, good value
# 240: vanilla oak, oak vanilla, chocolate oak, oak cherry, oak
# 241: chocolate oak, vanilla oak, oak vanilla, oak, oak cherry
# 242: chocolate oak, vanilla oak, oak vanilla, oak blackberry, oak cherry
# 243: fruity, fruit, fruit flavor, fruits, strawberry
# 244: wine, alcohol, drink, easy drink, drinking

# %%
file = 'wr_param_study_02'

path = 'sample_data'
path_src = '/content/drive/MyDrive/Colab\ Notebooks/'

f = f'{path}/{file}.csv'
df_result.to_csv(f, index = False)

# !cp {f} {path_src}

# %% [markdown]
# ## Review result

# %%
df_result.head()
# Out:
#    min_df  n_components  n_neighbors  min_dist  min_cluster_size  min_samples  \
# 0       1            10           10       0.0                20            2
# 1       1            10           10       0.0                20           10
# 2       1            10           10       0.0                20           20
# 3       1            10           10       0.0                50            5
# 4       1            10           10       0.0                50           25
#
#                                                    0  \
# 0  [fruity, delicious fruity, fruity good, tasty ...
# 1  [nice wine, good wine, great wine, excellent w...
# 2  [good, great, excellent, bad, good value, qual...
# 3  [good wine, wine, sauvignon, cabernet sauvigno...
# 4  [good, great, excellent, good value, bad, best...
#
#                                                    1  \
# 0  [good value money, money good value, good valu...
# 1  [vanilla oak blackberry, oak blackberry vanill...
# 2  [nice chardonnay, chardonnay, good chardonnay,...
# 3  [nice chardonnay, chardonnay, good chardonnay,...
# 4  [nice chardonnay, chardonnay, good chardonnay,...
#
#                                                    2  \
# 0  [chilean cabernet sauvignon, cabernet sauvigno...
# 1  [nice chardonnay, good chardonnay, chardonnay,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    3  \
# 0  [citrus tropical, citrus pear tropical, pear c...
# 1  [fruity, fruity good, tasty fruity, sweet frui...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    4  \
# 0  [chilean wine, wine chile, chilean wine wine, ...
# 1  [sour taste, bitter, retrospect add tasted, sw...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    5  \
# 0  [oak, oak oak, vanilla oak, oak vanilla, butte...
# 1  [good value money, money good value, good valu...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    6  \
# 0  [fruity scent, citrus scent, aromatic fruity, ...
# 1  [drink easy, easy drinking, easy drink, drink ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    7  \
# 0  [håkon rekdal, like håkon rekdal, rekdal, håko...
# 1  [citrus tropical, citrus pear tropical, pear c...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    8  \
# 0  [medium tannins, medium tannin, soft tannins, ...
# 1  [smooth dry, flavor smooth, dry smooth, delici...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    9
# 0  [easy drink good, drink easy, easy drinking, l...
# 1  [cabernet sauvignon, chilean cabernet sauvigno...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# case 1: compapre topic 0's
res_df = df_result[0].str.join(', ')
res_docs = res_df.to_list()

# %%
# caes 2: compare models with 10 topics
n = range(10)

res_df = df_result[n].apply(lambda x: x.str.join(', ')).stack()

res_docs = []
res_docs_id = [] # save param set and topic id for res_docs

for idx, s in res_df.items():
    if s is None:
        break
    res_docs.append(s)
    i = '_'.join([str(x) for x in idx])
    res_docs_id.append(i)
len(res_docs)
# Out:
# 1218

# %%
random_state = 42

umap_model = UMAP(min_dist=0.0, random_state=random_state)

topic_model = BERTopic(
    umap_model = umap_model,
    calculate_probabilities=True
    )

topics, probs = topic_model.fit_transform(res_docs)

topic_model.get_topic_info().head()
# Out:
#    Topic  Count                                  Name  \
# 0     -1     54             -1_rekdal_hkon_easy_drink
# 1      0     73  0_chardonnay_fairly_chardonnays_like
# 2      1     45         1_money_value_excellent_price
# 3      2     37  2_chardonnay_oaky_fairly_chardonnays
# 4      3     36              3_sour_bitter_tasted_add
#
#                                       Representation  \
# 0  [rekdal, hkon, easy, drink, fruity, smh, drink...
# 1  [chardonnay, fairly, chardonnays, like, chile,...
# 2  [money, value, excellent, price, good, great, ...
# 3  [chardonnay, oaky, fairly, chardonnays, chile,...
# 4  [sour, bitter, tasted, add, taste, aftertaste,...
#
#                                  Representative_Docs
# 0  [drink easy, easy drinking, easy drink, drink ...
# 1  [nice chardonnay, chardonnay, good chardonnay,...
# 2  [good value money, money good value, good valu...
# 3  [nice chardonnay, good chardonnay, chardonnay,...
# 4  [sour taste, taste sour, sour good, sour bitte...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d2eb1447-3106-4cf0-842d-328ecdde352a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2eb1447-3106-4cf0-842d-328ecdde352a")) {                    Plotly.newPlot(                        "d2eb1447-3106-4cf0-842d-328ecdde352a",                        [{"customdata":[[0,"chardonnay | fairly | chardonnays | like | chile",73],[1,"money | value | excellent | price | good",45],[2,"chardonnay | oaky | fairly | chardonnays | chile",37],[3,"sour | bitter | tasted | add | taste",36],[4,"vanilla | chocolate | oak | wood | cherry",36],[5,"cabernet | sauvignon | chilean | wines | sauv",31],[6,"fruity | sweet | light | tasty | intense",30],[7,"bom | quite | pretty | surprisingly | good",30],[8,"wine | nice | light | great | wines",29],[9,"blackberry | cherry | vanilla | oak | pepper",28],[10,"daily | table | white | wine | red",28],[11,"best | quality | pleasant | bad | better",28],[12,"sauvignon | cabernet | carmenere | australian | ordinary",27],[13,"money | value | price | good | great",26],[14,"2022 | mart | 2023 | 2021 | 08",26],[15,"better | pleasant | bad | fresh | price",25],[16,"wine | cheap | delicious | tried | nice",24],[17,"tropical | pear | citrus | thailand | lemon",22],[18,"chardonnay | oaky | chile | fairly | chardonnays",21],[19,"tropical | citrus | pear | thailand | peach",20],[20,"flavors | black | strawberry | cherry | vanilla",20],[21,"chilean | classic | chile | wines | american",20],[22,"tannin | medium | tannins | scent | aromatic",19],[23,"drink | easy | drinkable | drinking | drinker",19],[24,"dry | smooth | sweet | watery | light",19],[25,"taste | tasty | striking | delicious | tastes",18],[26,"oak | butter | chocolate | oaky | vanilla",18],[27,"table | white | wine | red | wines",18],[28,"value | money | excellent | great | good",18],[29,"oak | flavour | chocolate | vanilla | butter",17],[30,"wine | nice | wines | great | excellent",17],[31,"bad | just | decent | really | worse",17],[32,"fruity | light | sweet | enjoyable | intense",17],[33,"black | cherry | strawberry | oak | vanilla",16],[34,"blackberry | blackcurrant | cherry | oak | vanilla",16],[35,"value | price | money | excellent | great",16],[36,"money | value | excellent | great | good",16],[37,"notes | strong | wine | supermarket | nose",15],[38,"grape | cabernet | chilean | sauvignon | wines",15],[39,"cabernet | sauvignon | red | like | chilean",15],[40,"easy | drink | drinking | drinker | drinkable",15],[41,"wine | nice | red | great | wines",15],[42,"alcohol | quality | sauvignon | pleasant | high",15],[43,"white | wine | nice | wines | great",14],[44,"white | wine | nice | wines | great",14],[45,"flavors | chocolate | strawberry | vanilla | oak",14],[46,"easy | drink | drinkable | inexpensive | drinker",14],[47,"ruby | color | red | dark | deep",13],[48,"sauv | cabernet | cab | chilean | sauvignon",13],[49,"light | wine | nice | wines | great",12],[50,"sauvignon | cabernet | chilean | cab | wines",12],[51,"value | excellent | money | great | good",12],[52,"smooth | slightly | dry | flavor | sour",11],[53,"black | sweetness | vanilla | oak | bad",11],[54,"don | chardonnay | fairly | chardonnays | chile",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[73,45,37,36,36,31,30,30,29,28,28,28,27,26,26,25,24,22,21,20,20,20,19,19,19,18,18,18,18,17,17,17,17,16,16,16,16,15,15,15,15,15,15,14,14,14,14,13,13,12,12,12,11,11,11],"sizemode":"area","sizeref":0.045625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-4.7033576965332 ...

# %%
#topic_model.visualize_distribution(probs[0])

# %%
from sentence_transformers import SentenceTransformer

# Larger values of min_dist will focus on the preservation of the broad topological structure.
min_dist=0.1 #0.9

embedding_model = SentenceTransformer(st_id)
res_embeddings = embedding_model.encode(res_docs, show_progress_bar=False)

res_reduced = UMAP(n_components=2, random_state=random_state, min_dist=min_dist).fit_transform(res_embeddings)

# %%
#d = res_docs
#d = [f'{i}: {rec[0]}' for i, rec in pd.DataFrame(res_df).iterrows()]
d = [f'{x}:{y}' for x, y in zip(res_docs_id, res_docs)]

topic_model.visualize_documents(d, reduced_embeddings=res_reduced)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id
"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.034553115653659,0.043961590675943074,0.054504355892774185,0.08942351762714285,0.09959209831358351],"y":["good  ","price  ","excellent  ","value  ","money  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.06847828457257707,0.07788973382815771,0.07788973382815771,0.10240644341544995,0.14597986896428214],"y":["chile  ","chardonnays  ","fairly  ","oaky  ","chardonnay  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.11979321924944589,0.1252247990595817,0.1264233489728378,0.1588046001791974,0.3306016862615882],"y":["taste  ","add  ","tasted  ","bitter  ","sour  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.07423033369195473,0.07561364337781594,0.10587649980455265,0.10860116153627694,0.10926002533779954],"y":["cherry  ","wood  ","oak  ","chocolate  ","vanilla  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03658435199531421,0.05149280244989742,0.09231862095799538,0.13205998848925238,0.14989757652382016],"y":["sauv  ","wines  ","chilean  ","sauvignon  ","cabernet  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.053194099537096994,0.06324077915228278,0.09023947598175487,0.10140232293610876,0.27067077199329265],"y":["intense  ","tasty  ","light  ","sweet  ","fruity  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.07095459860087067,0.07924172101152412,0.11572254296483206,0.1437809560966471,0.22715962529753894],"y":["good  ","surprisingly  ","pretty  ","quite  ","bom  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444, ...

# %% [markdown]
# ### Topics per Class

# %%
# param set as class
classes = res_df.index.get_level_values(0)

# %%
len(classes), len(res_docs)
# Out:
# (1218, 1218)

# %%
topics_per_class = topic_model.topics_per_class(res_docs, classes=classes)

# %%
topic_model.visualize_topics_per_class(topics_per_class,
                                       #top_n_topics=10,
                                       normalize_frequency = False,
                                       #width=1000, height=500
                                       )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="227f4f06-1c52-408c-bd45-24d86823fdb1" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("227f4f06-1c52-408c-bd45-24d86823fdb1")) {                    Plotly.newPlot(                        "227f4f06-1c52-408c-bd45-24d86823fdb1",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays, fairly, like, chile","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chardonnay, chardonnays ...

# %%
tid = 7
ps = range(110,120)
cond = (topics_per_class.Topic == tid) & (topics_per_class.Class.isin(ps))
topics_per_class.loc[cond]
# Out:
#      Topic                                   Words  Frequency  Class  \
# 572      7  quite, pretty, surprisingly, good, bom          2    110
# 595      7  quite, pretty, surprisingly, good, bom          2    117
# 599      7  quite, pretty, surprisingly, good, bom          2    118
# 601      7  quite, pretty, surprisingly, bom, good          2    119
#
#                                 Name
# 572  7_bom_quite_pretty_surprisingly
# 595  7_bom_quite_pretty_surprisingly
# 599  7_bom_quite_pretty_surprisingly
# 601  7_bom_quite_pretty_surprisingly

# %%
df_result.loc[ps]
# Out:
# index                                                  0  \
# 110    [oak vanilla, oak, oak blackberry, vanilla, ci...
# 111    [bad, oak vanilla, vanilla, good, oak blackber...
# 112    [good wine, wine, good, good value, excellent,...
# 113    [oak vanilla, chocolate, oak blackberry, oak, ...
# 114    [bad, good, good value, better, great, pleasan...
# 115    [oak vanilla, oak, oak blackberry, chocolate, ...
# 116    [oak vanilla, oak, oak blackberry, vanilla, ch...
# 117    [good wine, good value, oak, wine, quality, ca...
# 118    [good value, good wine, value, quality, bad, p...
# 119    [good wine, wine, sweetness, red fruit, delici...
#
# index                                                  1  \
# 110    [good wine, excellent wine, nice wine, wine go...
# 111    [good wine, excellent wine, nice wine, wine go...
# 112    [nice chardonnay, chardonnay, good chardonnay,...
# 113    [good wine, excellent wine, wine good, nice wi...
# 114    [good wine, excellent wine, great wine, nice w...
# 115    [good wine, excellent wine, wine good, nice wi...
# 116    [good wine, nice wine, wine good, great wine, ...
# 117    [nice chardonnay, chardonnay, good chardonnay,...
# 118    [nice chardonnay, good chardonnay, chardonnay,...
# 119    [nice chardonnay, chardonnay, good chardonnay,...
#
# index                                                  2  \
# 110    [nice chardonnay, chardonnay, good chardonnay,...
# 111    [cabernet sauvignon, chilean cabernet sauvigno...
# 112                                                  NaN
# 113    [cabernet sauvignon, chilean cabernet sauvigno...
# 114    [chilean cabernet sauvignon, cabernet sauvigno...
# 115    [chilean cabernet sauvignon, cabernet sauvigno...
# 116                                                  NaN
# 117    [good, good good, good great, great, good exce...
# 118    [good, good good, good great, great, good exce...
# 119    [good, good great, good good, great, good exce...
#
# index                                                  3  \
# 110    [ordinary cabernet sauvignon, cabernet sauvign...
# 111    [nice chardonnay, chardonnay, good chardonnay,...
# 112                                                  NaN
# 113    [nice chardonnay, chardonnay, good chardonnay,...
# 114                                                  NaN
# 115                                                  NaN
# 116                                                  NaN
# 117    [quite good, quite good good, good quite good,...
# 118    [quite good, quite good good, good quite good,...
# 119    [quite good, quite good good, good quite good,...
#
# index                                                  4  \
# 110    [good, good good, good great, great, good exce...
# 111    [chilean wine, wine chile, chilean wine wine, ...
# 112                                                  NaN
# 113                                                  NaN
# 114                                                  NaN
# 115                                                  NaN
# 116                                                  NaN
# 117                                                  NaN
# 118                                                  NaN
# 119                                                  NaN
#
# index                                                  5  \
# 110    [chilean wine, wine chile, chilean wines, chil...
# 111                                                  NaN
# 112                                                  NaN
# 113                                                  NaN
# 114                                                  NaN
# 115                                                  NaN
# 116                                                  NaN
# 117                                                  NaN
# 118                                                  NaN
# 119                                                  NaN
#
# index                                                  6  \
# 110    [quite good, quite good good, good quite good,...
# 111                                                  NaN
# 112                                                  NaN
# 113                                                  NaN
# 114                                                  NaN
# 115                                                  NaN
# 116                                                  NaN
# 117                                                  NaN
# 118                                                  NaN
# 119                                                  NaN
#
# index                                                  7    8    9
# 110    [indescribable favorite cabernet, good caberne...  NaN  NaN
# 111                                                  NaN  NaN  NaN
# 112                                                  NaN  NaN  NaN
# 113                                                  NaN  NaN  NaN
# 114                                                  NaN  NaN  NaN
# 115                                                  NaN  NaN  NaN
# 116                                                  NaN  NaN  NaN
# 117                                                  NaN  NaN  NaN
# 118                                                  NaN  NaN  NaN
# 119                                                  NaN  NaN  NaN

# %%
i = 28
topic_model.visualize_distribution(probs[i])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2926dad4-5f8b-4a7b-bfd4-8b235e85fd54" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2926dad4-5f8b-4a7b-bfd4-8b235e85fd54")) {                    Plotly.newPlot(                        "2926dad4-5f8b-4a7b-bfd4-8b235e85fd54",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[1.0],"y":["\u003cb\u003eTopic 41\u003c\u002fb\u003e: wine_nice_red_great_win..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outs ...
